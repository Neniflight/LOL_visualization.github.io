# %%
import pandas as pd
import numpy as np

# %%
league_df_2 = pd.read_csv("../data/2023_LoL_esports_match_data_from_OraclesElixir.csv")
league_df_2['league'].unique()
# Out:
# /var/folders/q9/30fvw2z964jc870446_qqmwc0000gn/T/ipykernel_14686/2076871435.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   league_df_2 = pd.read_csv("../data/2023_LoL_esports_match_data_from_OraclesElixir.csv")
# array(['LFL2', 'DDH', 'EL', 'LPL', 'GL', 'LCKC', 'NEXO', 'UL', 'LVP SL',
#        'LCK', 'LFL', 'PRM', 'LMF', 'SL (LATAM)', 'VL', 'CBLOL', 'LEC',
#        'NACL', 'LCO', 'CBLOLA', 'LHE', 'NLC', 'GLL', 'ESLOL', 'LLA',
#        'EBL', 'TCL', 'PGN', 'LPLOL', 'LCS', 'HM', 'LJL', 'HC', 'AL',
#        'PCS', 'LDL', 'VCS', 'EM', 'MSI', 'LAS', 'LRN', 'LRS', 'EPL',
#        'LJLA', 'CT', 'WLDs', 'CDF', 'IC'], dtype=object)

# %%
major_leagues = league_df_2[league_df_2['league'].isin(['LCK', 'LEC', 'LCS', 'LPL'])][['gameid', 'league', 'year', 'split', 'patch','participantid', 'playername', 'playerid', 'teamname', 'teamid', 'champion', 'ban1', 'ban2', 'ban3', 'ban4', 'ban5', 'result', 'cspm', 'monsterkills', 'earned gpm', 'kills','deaths', 'assists', 'vspm', 'teamkills', 'teamdeaths']]
major_leagues
# Out:
#                        gameid league  year   split  patch  participantid  \
# 204          9691-9691_game_1    LPL  2023  Spring  13.01              1
# 205          9691-9691_game_1    LPL  2023  Spring  13.01              2
# 206          9691-9691_game_1    LPL  2023  Spring  13.01              3
# 207          9691-9691_game_1    LPL  2023  Spring  13.01              4
# 208          9691-9691_game_1    LPL  2023  Spring  13.01              5
# ...                       ...    ...   ...     ...    ...            ...
# 119971  ESPORTSTMNT02_3231936    LEC  2023  Finals  13.15              8
# 119972  ESPORTSTMNT02_3231936    LEC  2023  Finals  13.15              9
# 119973  ESPORTSTMNT02_3231936    LEC  2023  Finals  13.15             10
# 119974  ESPORTSTMNT02_3231936    LEC  2023  Finals  13.15            100
# 119975  ESPORTSTMNT02_3231936    LEC  2023  Finals  13.15            200
#
#        playername                                   playerid         teamname  \
# ...

# %%
cleaned_df = major_leagues.dropna(subset=['cspm'])
cleaned_df.head(5)
# Out:
#                gameid league  year   split  patch  participantid playername  \
# 204  9691-9691_game_1    LPL  2023  Spring  13.01              1  Xiaolaohu
# 205  9691-9691_game_1    LPL  2023  Spring  13.01              2      haoye
# 206  9691-9691_game_1    LPL  2023  Spring  13.01              3       Care
# 207  9691-9691_game_1    LPL  2023  Spring  13.01              4        Lwx
# 208  9691-9691_game_1    LPL  2023  Spring  13.01              5       Lele
#
#                                       playerid         teamname  \
# 204  oe:player:0e42126e417733263459e2b54ae7e2a  FunPlus Phoenix
# 205  oe:player:1e9df7dacc21aca9011a58eac5abae5  FunPlus Phoenix
# 206  oe:player:6bc43cc1537fa4ac6295b4899e972cf  FunPlus Phoenix
# 207  oe:player:ce76a8fc639b0cc96da48c76bc0bbeb  FunPlus Phoenix
# 208  oe:player:ad991b9f2f7e553d4eefb9f5d06afc9  FunPlus Phoenix
#
#                                       teamid  ... result     cspm  \
# ...

# %%
#since data inputted sequentially, it is a safe bet to impute the patch with the rows before
def fill_patch()
cleaned_df[cleaned_df['patch'].isna()]
# Out:
#                    gameid league  year   split  patch  participantid  \
# 54540  10011-10011_game_1    LPL  2023  Spring    NaN              1
# 54541  10011-10011_game_1    LPL  2023  Spring    NaN              2
# 54542  10011-10011_game_1    LPL  2023  Spring    NaN              3
# 54543  10011-10011_game_1    LPL  2023  Spring    NaN              4
# 54544  10011-10011_game_1    LPL  2023  Spring    NaN              5
# 54545  10011-10011_game_1    LPL  2023  Spring    NaN              6
# 54546  10011-10011_game_1    LPL  2023  Spring    NaN              7
# 54547  10011-10011_game_1    LPL  2023  Spring    NaN              8
# 54548  10011-10011_game_1    LPL  2023  Spring    NaN              9
# 54549  10011-10011_game_1    LPL  2023  Spring    NaN             10
# 54564  10011-10011_game_2    LPL  2023  Spring    NaN              1
# 54565  10011-10011_game_2    LPL  2023  Spring    NaN              2
# 54566  10011-10011_game_2    LPL  2023  Spring    NaN              3
# ...

# %%
league_df['league'].unique()
# Out:
# array(['LCK', 'LEC', 'LCS'], dtype=object)

# %%
yo = [print(i) for i in list(league_df.columns)]
# Out:
# gameid
# datacompleteness
# url
# league
# year
# split
# playoffs
# date
# game
# patch
# participantid
# side
# position
# playername
# playerid
# teamname
# teamid
# champion
# ban1
# ban2
# ban3
# ban4
# ban5
# gamelength
# result
# kills
# deaths
# assists
# teamkills
# teamdeaths
# doublekills
# triplekills
# quadrakills
# pentakills
# firstblood
# firstbloodkill
# firstbloodassist
# firstbloodvictim
# team kpm
# ckpm
# firstdragon
# dragons
# opp_dragons
# elementaldrakes
# opp_elementaldrakes
# infernals
# mountains
# clouds
# oceans
# chemtechs
# hextechs
# dragons (type unknown)
# elders
# opp_elders
# firstherald
# heralds
# opp_heralds
# firstbaron
# barons
# opp_barons
# firsttower
# towers
# opp_towers
# firstmidtower
# firsttothreetowers
# turretplates
# opp_turretplates
# inhibitors
# opp_inhibitors
# damagetochampions
# dpm
# damageshare
# damagetakenperminute
# damagemitigatedperminute
# wardsplaced
# wpm
# wardskilled
# wcpm
# controlwardsbought
# visionscore
# ...

# %%
relevant_cols_df = league_df[['gameid', 'league', 'year', 'split', 'patch','participantid', 'playername', 'playerid', 'teamname', 'teamid', 'champion', 'ban1', 'ban2', 'ban3', 'ban4', 'ban5', 'result', 'csdiffat15', 'xpdiffat15', 'monsterkills', 'earned gpm', 'kills','deaths', 'assists', 'vspm']]
relevant_cols_df.head(20)
# Out:
#                    gameid league  year   split  patch  participantid  \
# 0   ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01              1
# 1   ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01              2
# 2   ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01              3
# 3   ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01              4
# 4   ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01              5
# 5   ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01              6
# 6   ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01              7
# 7   ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01              8
# 8   ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01              9
# 9   ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01             10
# 10  ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01            100
# 11  ESPORTSTMNT06_2753012   LFL2  2023  Spring  13.01            200
# 12  ESPORTSTMNT06_2754023   LFL2  2023  Spring  13.01              1
# ...

# %%
team_df = relevant_cols_df[(relevant_cols_df['participantid'] == 100) | (relevant_cols_df['participantid'] == 200)]
players_df = relevant_cols_df[~((relevant_cols_df['participantid'] == 100) | (relevant_cols_df['participantid'] == 200))]

# %%
players_df.isna().sum()
# Out:
# gameid               0
# league               0
# year                 0
# split            21540
# patch                0
# participantid        0
# playername          26
# playerid           922
# teamname             0
# teamid            1095
# champion             0
# ban1               275
# ban2               180
# ban3               440
# ban4               325
# ban5               570
# result               0
# csdiffat15           0
# xpdiffat15           0
# monsterkills         0
# earned gpm           0
# kills                0
# deaths               0
# assists              0
# vspm                 0
# dtype: int64

# %%
players_df[players_df['playername'].isna()]
# Out:
#                        gameid league  year   split  patch  participantid  \
# 24698   ESPORTSTMNT02_3161006    PGN  2023  Spring  13.03              3
# 24760   ESPORTSTMNT02_3161035    PGN  2023  Spring  13.03              5
# 25514   ESPORTSTMNT02_3160621    PGN  2023  Spring  13.03              3
# 29923   ESPORTSTMNT02_3170083    PGN  2023  Spring  13.03              8
# 30991   ESPORTSTMNT02_3171378    PGN  2023  Spring  13.03              8
# 31915   ESPORTSTMNT02_3169606    PGN  2023  Spring  13.03              8
# 58332   ESPORTSTMNT05_3220607     EM  2023  Spring  13.06              1
# 58333   ESPORTSTMNT05_3220607     EM  2023  Spring  13.06              2
# 129405  ESPORTSTMNT03_3228169    VCS  2024     NaN  13.19             10
# 129429  ESPORTSTMNT03_3228183    VCS  2024     NaN  13.19             10
# 129484  ESPORTSTMNT03_3228197    VCS  2024     NaN  13.19              5
# 129501  ESPORTSTMNT03_3228207    VCS  2024     NaN  13.19             10
# ...
